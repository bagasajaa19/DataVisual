# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['januari','febuari','maret','april','mei','juni','juli','agustus','september','oktober','november','desember']

#pengeluaran antara 500.000 - 2.000.000

Minggu_1 = np.random.randint(500000,2000001,12)
Minggu_2 = np.random.randint(500000,2000001,12)
Minggu_3 = np.random.randint(500000,2000001,12)
Minggu_4 = np.random.randint(500000,2000001,12)

data = {
    'bulan' : bulan,
    'Minggu_1' : Minggu_1,
    'Minggu_2' : Minggu_2,
    'Minggu_3' : Minggu_3,
    'Minggu_4' : Minggu_4
}

df = pd.DataFrame(data)

df['Total_Pengeluaran'] = df[['Minggu_1','Minggu_2','Minggu_3','Minggu_4']].sum(axis=1)
df
# Out:
#         bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  Total_Pengeluaran
# 0     januari    878581   1502854   1783266   1350176            5514877
# 1     febuari    601327   1899136   1156606   1724568            5381637
# 2       maret    697860    802698   1799170   1978102            5277830
# 3       april    556732   1421200   1379120    782248            4139300
# 4         mei   1422576   1496623   1108924   1272342            5300465
# 5        juni   1725657   1057371   1252720   1123875            5159623
# 6        juli   1043497   1842787   1632803    644013            5163100
# 7     agustus   1404507   1617332   1797870   1178576            5998285
# 8   september   1192151    614069    952911   1245317            4004448
# 9     oktober    724350   1101533    517009   1512813            3855705
# 10   november    872119   1968886   1568237   1563834            5973076
# 11   desember   1000347    934159   1248171   1093918            4276595

# %%
#Total pengeluaran Per Bulan -> BAR

plt.figure(figsize=(12,6))#Canvas dengan ukuran width,height (inch)
plt.title('Total Pengeluaran Per Bulan')
plt.bar(df['bulan'],df['Total_Pengeluaran'],color='brown')
plt.xticks(rotation=45)
plt.ylabel("Rupiah")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#Scatter Plot untuk analisa data pengeluaran per minggu per bulan
plt.figure(figsize=(12,6))
for minggu in ['Minggu_1','Minggu_2','Minggu_3','Minggu_4']:
    plt.plot(df['bulan'],df[minggu],marker='o',label=minggu)
    
plt.title("Pengeluaran Per Minggu")
plt.xlabel('bulan')
plt.ylabel('Pengeluaran (Rupiah)')
plt.grid(axis='x')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Pie Chart -> Prosentase
plt.figure(figsize=(10,7))
plt.pie(df['Total_Pengeluaran'],labels=df['bulan'],startangle=90,autopct='%1.1f%%')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

df['bulan_angka'] = np.arange(1,13)

X = df[['bulan_angka']]
y = df['Total_Pengeluaran']

model = LinearRegression()

model.fit(X,y)

prediksi = model.predict([[13]])[0]
print(f"Hasil Prediksi adalah :{prediksi:,.0f}")
# Out:
# Hasil Prediksi adalah :5,111,285
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('disparbud-od_jumlah_penginapan_remaja_berdasarkan_infrastruktur_data.csv')
df
# Out:
#       id kode_provinsi nama_provinsi kode_kabupaten_kota nama_kabupaten_kota  \
# 0      0            32    JAWA BARAT                3201     KABUPATEN BOGOR
# 1      1            32    JAWA BARAT                3202  KABUPATEN SUKABUMI
# 2      2            32    JAWA BARAT                3203   KABUPATEN CIANJUR
# 3      3            32    JAWA BARAT                3204   KABUPATEN BANDUNG
# 4      4            32    JAWA BARAT                3205     KABUPATEN GARUT
# ..   ...           ...           ...                 ...                 ...
# 311  311    JAWA BARAT          3272       KOTA SUKABUMI               KAMAR
# 312  312    JAWA BARAT          3272       KOTA SUKABUMI        TEMPAT TIDUR
# 313  313    JAWA BARAT          3278    KOTA TASIKMALAYA          PENGINAPAN
# 314  314    JAWA BARAT          3278    KOTA TASIKMALAYA               KAMAR
# 315  315    JAWA BARAT          3278    KOTA TASIKMALAYA        TEMPAT TIDUR
#
#      jumlah_penginapan satuan  tahun
# 0                    2   UNIT   2014
# 1                    0   UNIT   2014
# 2                    1   UNIT   2014
# 3                    0   UNIT   2014
# 4                    0   UNIT   2014
# ..                 ...    ...    ...
# 311                 25   UNIT   2017
# 312                 65   UNIT   2017
# 313                  0   UNIT   2017
# 314                  0   UNIT   2017
# 315                  0   UNIT   2017
#
# [316 rows x 8 columns]

# %% [markdown]
# <p>Skenario Analisis Data Penginapan</p>
# <ol>
#     <li>Wilayah yang diteliti adalah jawa barat</li>
#     <li>Jumlah Penginapan paling banyak ada di Kabupaten Bandung Barat yaitu 14 unit </li>
#     <li>Jumlah penginapan paling dikit ada di Kabupaten Garut yaitu 0 unit </li>
#     <li>Kota Bogor Menjadi penginapan Tempat tidur Terbanyak dengan 223 penginapan di tahun 2015</li>
#     <li>Kabupaten Bandung Barat menjadi penginapan Tempat tidur terbanyak dengan 312 penginapan di tahun 2016</li>
#     <li>Kota Cimahi menjadi penginaman Tempat tidur terbanyak di 220 penginapan di tahun 2017</li>
#
# </ol>
